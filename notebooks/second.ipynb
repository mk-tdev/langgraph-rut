# %%
### Imports

from typing import Dict, TypedDict, List
from langgraph.graph import StateGraph
from IPython.display import Image, display

# %%
class AgentState(TypedDict):
  values: List[int]
  name: str
  result: str

# %%
def process_values(state: AgentState) -> AgentState:
  """Process values"""
  
  state["result"] = "The sum of {} is {}".format(state["values"], sum(state["values"]))
  return state

# %%
graph=StateGraph(AgentState)
graph.add_node("process_values", process_values)
graph.set_entry_point("process_values")
graph.set_finish_point("process_values")
app = graph.compile()

# %%
display(Image(app.get_graph().draw_mermaid_png()))

# %%
result = app.invoke(
  {"values": [1,2,4,5]},
)
result
# Out:
# {'values': [1, 2, 4, 5], 'result': 'The sum of [1, 2, 4, 5] is 12'}
